# %%
# This will batch convert cifs to pdbs should you need it for MPMC or anything else

# %%
from ccdc import io
from ccdc.descriptors import CrystalDescriptors
import os

# %%
current_dir = os.path.join(os.getcwd(), "cifs")
files_in_dir = os.listdir(current_dir)
cif_files = [os.path.join("cifs", file) for file in files_in_dir if file.endswith(".cif")]

# %%
mofs = [] 
count = 0
temp_dir = os.path.join('pdbs')
os.rmdir(temp_dir)
os.mkdir(temp_dir, 0o744)
for cif in cif_files: 
    reader = io.EntryReader(cif) 
    for mol in reader: 
        crystal = mol.crystal 
        # https://downloads.ccdc.cam.ac.uk/documentation/API/modules/io_api.html#ccdc.io.CrystalWriter
        file_name = os.path.basename(cif)
        file_name = os.path.splitext(file_name)
        print(file_name[0])
        file_path = os.path.join(temp_dir, file_name[0] + '.pdb')

        with io.CrystalWriter(os.path.join(temp_dir, file_name[0] + '.pdb'), append=True) as crystal_writer:
            crystal_writer.write(crystal)
# Out:
# ABAVIJ_clean
# ABAYIO_clean
# ABAYOU_clean
# ABEFUL_clean
# ABESUX_clean
# ABETAE_clean
# ABETIN_clean
# ABEXEM_clean
# ABEXEN_clean
# ABEXIQ_clean
# ABEXOW_clean
# ABEXUC_clean
# ABEYAJ_clean
# ABEYEN_clean
# ABEYIR_clean
# ABIXOZ_clean
# ABIYIV_clean
# ABULOB_clean
# ABUWOJ_clean
# ac403674p_si_001_clean
# ACAJIY_clean
# ACAJIZ_clean
# ACAJOF_clean
# ACAKUM_clean
# ACALIB_clean
# ACECIV_ion_b
# ACIBIY_clean
# ACIBOE_clean
# ACODON_clean
# ACODUT_clean
# ACOGAB_clean
# ACOGEF_clean
# ACOLEL_clean
# ACOLIP_clean
# ACOLOV_clean
# acs.cgd.5b01554_VAGNUP1452791_clean
# acs.cgd.5b01686_WAHFUJ1434675_clean
# acs.cgd.6b00163_UKEBOD1448508_clean
# acs.cgd.6b00463_OLOMUZ1451936_clean
# acs.chemmater.5b03723_cm5b03723_si_004_clean
# acs.chemmater.5b03723_cm5b03723_si_005_clean
# acs.chemmater.6b02817_cm6b02817_si_004_clean
# acs.chemrev.6b00346_cr6b00346_si_001_clean
# acscombsci.5b00188_24205_clean
# acscombsci.5b00188_3001288_clean
# acscombsci.5b00188_34903_clean
# acscombsci.5b00188_5013797_clean
# acscombsci.5b00188_5020072_clean
# acscombsci.5b00188_5024922_clean
# acscombsci.5b00188_5036495_clean
# acscombsci.5b00188_5040209_clean
# acscombsci.5b00188_8372_clean
# acs.inorgchem.5b02108_ic5b02108_si_002_clean
# acs.inorgchem.5b02378_ic5b02378_si_002_clean
# acs.inorgchem.5b02973_ic5b02973_si_002_clean
# acs.inorgchem.6b00081_ic6b00081_si_001_clean
# acs.inorgchem.6b00136_ic6b00136_si_002_clean
# acs.inorgchem.6b00276_ic6b00276_si_006_clean
# acs.inorgchem.6b00433_ic6b00433_si_002_clean
# acs.inorgchem.6b00894_ic6b00894_si_002_clean
# acs.inorgchem.6b00894_ic6b00894_si_003_clean
# acs.inorgchem.6b01211_ic6b01211_si_002_clean
# acs.inorgchem.6b01416_ic6b01416_si_004_clean
# acs.inorgchem.6b01569_ic6b01569_si_002_clean
# acs.inorgchem.6b01740_ic6b01740_si_002_clean
# acs.inorgchem.6b01762_ic6b01762_si_002_clean
# acs.inorgchem.6b02407_ic6b02407_si_002_clean
# acs.inorgchem.6b02407_ic6b02407_si_003_clean
# acs.inorgchem.6b02413_ic6b02413_si_002_clean
# acs.inorgchem.6b02514_ic6b02514_si_002_clean
# acs.inorgchem.6b02696_ic6b02696_si_002_clean
# acs.jchemed.6b00258_ed6b00258_si_005_clean
# acs.jpcc.6b08594_UiO66_Ce2Zr4_opt_clean
# acs.jpcc.6b08594_Zn2Cd6MOF5_opt_clean
# ACUBAB_clean
# ACUFEK_clean
# ACUJOZ_manual
# ACUTOI_clean
# ADABIS_clean
# ADABUE_clean
# ADARAA_clean
# ADASAB_charged
# ADASEF_clean
# ADASIJ_clean
# ADASOP_clean
# ADASUV_clean
# ADATAC_clean
# ADATEG_manual
# ADATIK_clean
# ADATOQ_clean
# ADATUW_clean
# ADAVAE_clean
# ADAVEI_clean
# ADAVIM_clean
# ADAXEK_clean
# ADAXIO_clean
# ADEGIA01_clean
# ADEGIA_clean
# ADIQEL_clean
# ADOBAX_charged
# ADOBEB_charged
# ADOBIF_clean
# ADOBOL_charged
# ADOBUR_charged
# ADOCEC_clean
# ADODAA_charged
# ADODII_clean
# ADODOO_clean
# ADODUU_clean
# ADOGEH_clean
# ADUROI_clean
# ADUWIH_clean
# ADUWON_clean
# AFEDIA_clean
# AFEJOK_ion_b
# AFENEE_clean
# AFIPAH_clean
# AFITEP_clean
# AFITUF_clean
# AFIXAO_clean
# AFIXES_clean
# AFOQUI_clean
# AFOTOF_clean
# AFOTUL_clean
# AFOVAT_clean
# AFOVEX_clean
# AFOVIB_clean
# AFOVOH_clean
# AFOYAW_clean
# AFOYEB_clean
# AFOYIE_clean
# AFOYOK_clean
# AFUKET_clean
# AFUKIX_clean
# AFUPEX_clean
# AGABIU_clean
# AGARUW_clean
# AGAYIQ_clean
# AGAYOW_clean
# AGESIP_clean
# AGIMOU_clean
# AGIREP_clean
# AGOFEJ_clean
# AGONAM_clean
# AGONEQ_clean
# AGOVOJ_clean
# AGUBUA_clean
# AGUTUS_clean
# AGUVOO_charged
# AGUWUV_clean
# AHAMAY_clean
# AHEBAS_clean
# AHEQAH_clean
# AHINIP_clean
# AHIYOH_clean
# AHIYUN_clean
# AHOBEG_clean
# AHOJUC_clean
# AHOKAJ_clean
# AHOKIR01_clean
# AHOKIR_clean
# AHOKOX_clean
# AHOZAA_clean
# AHUFIU_clean
# AHUTIH01_clean
# AHUTIH_clean
# AJAKON_clean
# AJAMEF_clean
# AJAYIT_clean
# AJIGIL_clean
# AJINOY_clean
# AJOTEY_clean
# AJOVEB_clean
# AJOXAA_clean
# AJUNOK_clean
# AKEDIF_clean
# AKOBAF_clean
# AKOHEO_clean
# AKOXIJ_clean
# AKUHOD01_clean
# AKUHOD03_clean
# AKUHOD_clean
# AKUKUO_clean
# ALAHUS_clean
# ALALUU01_clean
# ALALUU_clean
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 8
#       6 for cif in cif_files:
#       7     reader = io.EntryReader(cif)
# ----> 8     for mol in reader:
#       9         crystal = mol.crystal
#      10         # https://downloads.ccdc.cam.ac.uk/documentation/API/modules/io_api.html#ccdc.io.CrystalWriter
#
# File ~/.conda/envs/csd/lib/python3.9/site-packages/ccdc/io.py:932, in _DatabaseReader.entries(self)
#     930 '''Generator for entries in the database.'''
#     931 for i in range(self._db.size()):
# --> 932     yield self._make_entry(self._enumerator.entry(i))
#
# File ~/.conda/envs/csd/lib/python3.9/site-packages/ccdc/io.py:1173, in _CifReader._make_entry(self, e)
#    1172 def _make_entry(self, e):
# -> 1173     entry = Entry(e)
#    1174     i = self._enumerator.index(e.identifier())
#    1175     cif_db = FileFormatsLib.CrystalStructureDatabaseAsCifDatabase(self._db)
#
# File ~/.conda/envs/csd/lib/python3.9/site-packages/ccdc/entry.py:296, in Entry.__init__(self, _entry)
#     294 if hasattr(self._entry, 'chemical_diagram') and self._entry.chemical_diagram() is None:
#     295     try:
# --> 296         self._make_diagram()
#     297     except RuntimeError:
#     298         pass
#
# File ~/.conda/envs/csd/lib/python3.9/site-packages/ccdc/entry.py:279, in Entry._make_diagram(self)
#     277 def _make_diagram(self):
#     278     cdg = ChemistryLib.ChemicalDiagramGenerator()
# --> 279     m = self._entry.crystal_structure().editable_molecule()
#     280     diag = cdg.create_chemical_diagram(m)
#     281     ChemistryLib.normalise_diagram(diag)
#
# File ~/.conda/envs/csd/lib/python3.9/site-packages/ccdc/_lib/DatabaseEntryLib39.py:3103, in CrystalStructureDatabaseEntry.crystal_structure(self)
#    3102 def crystal_structure(self):
# -> 3103     return _DatabaseEntryLib39.CrystalStructureDatabaseEntry_crystal_structure(self)
#
# KeyboardInterrupt:
