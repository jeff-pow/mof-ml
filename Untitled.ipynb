# %%
from ccdc import io
from ccdc.descriptors import CrystalDescriptors
import pandas as pd
import numpy as np
import sklearn as sk
import os

# %%
df = pd.read_csv('mof_data.csv')

# %%
df
# Out:
#        Unnamed: 0  habit  disorder  void_volume          molecule_name  \
# 0               0    NaN         0    15.229167  cifs/ABAVIJ_clean.cif
# 1               1    NaN         0    63.627168  cifs/ABAYIO_clean.cif
# 2               2    NaN         0    63.303495  cifs/ABAYOU_clean.cif
# 3               3    NaN         0    18.512397  cifs/ABEFUL_clean.cif
# 4               4    NaN         0    49.359268  cifs/ABESUX_clean.cif
# ...           ...    ...       ...          ...                    ...
# 11655       11655    NaN         0    34.653061  cifs/ZUVTEP_clean.cif
# 11656       11656    NaN         0    28.114286  cifs/ZUWWAP_clean.cif
# 11657       11657    NaN         0    65.633333  cifs/ZUWXUM_clean.cif
# 11658       11658    NaN         0    40.611562  cifs/ZUXPOZ_clean.cif
# 11659       11659    NaN         0    66.358925  cifs/ZUZZEB_clean.cif
#
#       crystal_system  calculated_density  packing_coefficient  2theta_0  \
# ...
